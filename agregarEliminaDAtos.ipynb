# %%
import pandas as pd
import numpy as np

# %%
  n_filtrado = pd.read_csv('./TutorialPandas/formatoExcel.csv')
  n_filtrado
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
n_filtrado.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
#borra sin afectar el archoriginal
n_filtrado.drop('Name', axis = 1).head(2)
# Out:
#          Author  User Rating  Reviews  Price  Year        Genre
# 0      JJ Smith          4.7    17350      8  2016  Non Fiction
# 1  Stephen King          4.6     2052     22  2011      Fiction

# %%
#borra en el archoriginal
n_filtrado.drop('Name', axis = 1, inplace= True)
# Out:
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 6 columns]

# %%
del n_filtrado['Reviews']

# %%
n_filtrado
# Out:
#                        Author  User Rating  Price  Year        Genre
# 0                    JJ Smith          4.7      8  2016  Non Fiction
# 1                Stephen King          4.6     22  2011      Fiction
# 2          Jordan B. Peterson          4.7     15  2018  Non Fiction
# 3               George Orwell          4.7      6  2017      Fiction
# 4    National Geographic Kids          4.8     12  2019  Non Fiction
# ..                        ...          ...    ...   ...          ...
# 545               Jeff Kinney          4.9      8  2019      Fiction
# 546               Jen Sincero          4.7      8  2016  Non Fiction
# 547               Jen Sincero          4.7      8  2017  Non Fiction
# 548               Jen Sincero          4.7      8  2018  Non Fiction
# 549               Jen Sincero          4.7      8  2019  Non Fiction
#
# [550 rows x 5 columns]

# %%
n_filtrado.drop(range(0,10), axis=0).head(2)
# Out:
#               Author  User Rating  Price  Year        Genre
# 10   Fredrik Backman          4.6      8  2017      Fiction
# 11  Larry Schweikart          4.6      2  2010  Non Fiction

# %% [markdown]
# ## agregar nuevas columnas

# %% [markdown]
# n_filtrado.head(2)

# %%
n_filtrado.head(2)
# Out:
#          Author  User Rating  Price  Year        Genre
# 0      JJ Smith          4.7      8  2016  Non Fiction
# 1  Stephen King          4.6     22  2011      Fiction

# %%
n_filtrado['NuevaColumna'] = np.NaN
n_filtrado
# Out:
#                        Author  User Rating  Price  Year        Genre  \
# 0                    JJ Smith          4.7      8  2016  Non Fiction
# 1                Stephen King          4.6     22  2011      Fiction
# 2          Jordan B. Peterson          4.7     15  2018  Non Fiction
# 3               George Orwell          4.7      6  2017      Fiction
# 4    National Geographic Kids          4.8     12  2019  Non Fiction
# ..                        ...          ...    ...   ...          ...
# 545               Jeff Kinney          4.9      8  2019      Fiction
# 546               Jen Sincero          4.7      8  2016  Non Fiction
# 547               Jen Sincero          4.7      8  2017  Non Fiction
# 548               Jen Sincero          4.7      8  2018  Non Fiction
# 549               Jen Sincero          4.7      8  2019  Non Fiction
#
#      NuevaColumna
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# ...

# %%
np.arange(0,n_filtrado.shape[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\PRINCIPAL\Desktop\estudio\jupiter\agregarEliminaDAtos.ipynb Celda 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PRINCIPAL/Desktop/estudio/jupiter/agregarEliminaDAtos.ipynb#ch0000013?line=0'>1</a> np.arange(0,3,1,datetype=int)
#
# TypeError: arange() got an unexpected keyword argument 'datetype'

# %%
n_filtrado.append(n_filtrado)
# Out:
# C:\Users\PRINCIPAL\AppData\Local\Temp\ipykernel_2532\3876383266.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   n_filtrado.append(n_filtrado)
#                        Author  User Rating  Price  Year        Genre  \
# 0                    JJ Smith          4.7      8  2016  Non Fiction
# 1                Stephen King          4.6     22  2011      Fiction
# 2          Jordan B. Peterson          4.7     15  2018  Non Fiction
# 3               George Orwell          4.7      6  2017      Fiction
# 4    National Geographic Kids          4.8     12  2019  Non Fiction
# ..                        ...          ...    ...   ...          ...
# 545               Jeff Kinney          4.9      8  2019      Fiction
# 546               Jen Sincero          4.7      8  2016  Non Fiction
# 547               Jen Sincero          4.7      8  2017  Non Fiction
# ...

# %%
n_filtrado.drop(5, axis=0, inplace=True)
n_filtrado.head(3)
# Out:
#                 Author  Reviews  Price  Year
# 3        George Orwell    21424      6  2017
# 6  George R. R. Martin    19735     30  2014
# 7          Amor Towles    19699     15  2017

# %%
np.arange(0,n_filtrado[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
n_filtrado
# Out:
#                   Author  Reviews  Price  Year  tercera
# 3          George Orwell    21424      6  2017      NaN
# 6    George R. R. Martin    19735     30  2014      NaN
# 7            Amor Towles    19699     15  2017      NaN
# 8            James Comey     5983      3  2018      NaN
# 9        Fredrik Backman    23848      8  2016      NaN
# ..                   ...      ...    ...   ...      ...
# 545          Jeff Kinney     9413      8  2019      NaN
# 546          Jen Sincero    14331      8  2016      NaN
# 547          Jen Sincero    14331      8  2017      NaN
# 548          Jen Sincero    14331      8  2018      NaN
# 549          Jen Sincero    14331      8  2019      NaN
#
# [545 rows x 5 columns]

# %%
from cmath import nan


n_filtrado.append(550) = nan
# Out:
#   Input In [65]
#     n_filtrado.append(550) = nan
#     ^
# SyntaxError: cannot assign to function call
