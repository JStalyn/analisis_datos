# %%
import pandas as pd
import numpy as np

# %%
df_books = pd.read_csv('./clientes.csv',sep=';',header=0)
df_books
# Out:
#     horario  lunes   martes  miercoles  jueves   viernes  sabado   domingo   \
# 0         6     NaN       3          5        9        0        0         0
# 1         7     NaN       3          5        0        0        0         0
# 2         8     NaN       4          3        2        0        0         0
# 3         9     NaN       4          4        0        0        0         0
# 4        10     NaN       2          6        2        0        0         2
# 5        11     NaN       1          7        5        0        0         3
# 6        12     NaN       7          1       10        0        0         2
# 7        13     NaN       0          2        1        0        0         0
# 8        14     NaN       1          7        1        0        0         0
# 9        15     NaN       7          1        1        0        0         1
# 10       16     NaN       5          5        2        0        0         0
# ...

# %%
df_books.pivot_table(index='horario')
# Out:
#          domingo   jueves   jueves .1  lunes .1  martes  martes.1  miercoles  \
# horario
# 6               0        9          5         4       3         9          5
# 7               0        0          2         2       3         3          5
# 8               0        2          2         0       4         4          3
# 9               0        0          2         1       4         9          4
# 10              2        2         10        10       2        11          6
# 11              3        5          5        11       1         4          7
# 12              2       10         11         9       7         6          1
# 13              0        1          3         1       0         3          2
# 14              0        1          1         7       1         2          7
# 15              1        1          1         3       7         3          1
# 16              0        2          2         1       5         4          5
# ...

# %%
def two_times(value):
    return value * 2

# %%
df_books['horario'].apply(two_times)
# Out:
# 0     12
# 1     14
# 2     16
# 3     18
# 4     20
# 5     22
# 6     24
# 7     26
# 8     28
# 9     30
# 10    32
# 11    34
# 12    36
# 13    38
# 14    40
# Name: horario, dtype: int64

# %%
df_books['tabla'] = df_books['martes'].apply(two_times)
df_books
# Out:
#     horario  lunes   martes  miercoles  jueves   viernes  sabado   domingo   \
# 0         6     NaN       3          5        9        0        0         0
# 1         7     NaN       3          5        0        0        0         0
# 2         8     NaN       4          3        2        0        0         0
# 3         9     NaN       4          4        0        0        0         0
# 4        10     NaN       2          6        2        0        0         2
# 5        11     NaN       1          7        5        0        0         3
# 6        12     NaN       7          1       10        0        0         2
# 7        13     NaN       0          2        1        0        0         0
# 8        14     NaN       1          7        1        0        0         0
# 9        15     NaN       7          1        1        0        0         1
# 10       16     NaN       5          5        2        0        0         0
# ...

# %%
df_books ['martes1'] = df_books['martes'].apply(lambda x : x * 4)
df_books
# Out:
#     horario  lunes   martes  miercoles  jueves   viernes  sabado   domingo   \
# 0         6     NaN       3          5        9        0        0         0
# 1         7     NaN       3          5        0        0        0         0
# 2         8     NaN       4          3        2        0        0         0
# 3         9     NaN       4          4        0        0        0         0
# 4        10     NaN       2          6        2        0        0         2
# 5        11     NaN       1          7        5        0        0         3
# 6        12     NaN       7          1       10        0        0         2
# 7        13     NaN       0          2        1        0        0         0
# 8        14     NaN       1          7        1        0        0         0
# 9        15     NaN       7          1        1        0        0         1
# 10       16     NaN       5          5        2        0        0         0
# ...

# %%
miniarray = np.array([[7, 8],[2, 1],[2, 4]])
ultra  =np.shape(miniarray)
j = np.numdim(miniarray)
j
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\PRINCIPAL\Desktop\estudio\jupiter\pivot_melt.ipynb Celda 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/PRINCIPAL/Desktop/estudio/jupiter/pivot_melt.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> miniarray = np.array([[7, 8],[2, 1],[2, 4]])
#       <a href='vscode-notebook-cell:/c%3A/Users/PRINCIPAL/Desktop/estudio/jupiter/pivot_melt.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> ultra  =np.shape(miniarray)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PRINCIPAL/Desktop/estudio/jupiter/pivot_melt.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> j = np.numdim(miniarray)
#       <a href='vscode-notebook-cell:/c%3A/Users/PRINCIPAL/Desktop/estudio/jupiter/pivot_melt.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> j
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\__init__.py:313, in __getattr__(attr)
# ...
